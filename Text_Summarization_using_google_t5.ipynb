# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
model_name = "google-t5/t5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name).to(device)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def summarize_text(input_text, max_length=150, min_length=30):

    input_text = "summarize: " + input_text
    input_ids = tokenizer.encode(input_text, return_tensors="pt", max_length=512, truncation=True).to(device)

    summary_ids = model.generate(input_ids,
                                 num_beams=4,
                                 no_repeat_ngram_size=2,
                                 min_length=min_length,
                                 max_length=max_length,
                                 early_stopping=True)

    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    return summary

input_text = input("Enter any text: ")
summary = summarize_text(input_text)
print("Original Text Length:", len(input_text))
print("\nOriginal Text:")
print(input_text)
print("\nSummary Length:", len(summary))
print("\nSummary:")
print(summary)
# Out:
# Enter any text: The Internet of Things (IoT) is revolutionizing the way we interact with technology in our daily lives. IoT refers to the network of physical devices, vehicles, home appliances, and other items embedded with electronics, software, sensors, and network connectivity, which enables these objects to collect and exchange data. This interconnectedness allows for seamless communication between devices, leading to increased automation and efficiency in various sectors.  In smart homes, IoT devices like thermostats, lighting systems, and security cameras can be controlled remotely via smartphones, offering convenience and energy savings. In healthcare, wearable devices can monitor patients' vital signs and alert medical professionals in case of emergencies. The agricultural sector benefits from IoT through smart irrigation systems and crop monitoring sensors, optimizing resource use and increasing yields.  However, the rapid growth of IoT also raises concerns about data privacy and security. As more devices become connected, the potential for cyberattacks and data breaches increases. Additionally, the vast amount of data generated by IoT devices poses challenges in terms of storage, processing, and analysis.  Despite these challenges, the potential benefits of IoT are immense. From improving urban planning with smart city initiatives to enhancing manufacturing processes through industrial IoT applications, this technology is set to transform numerous aspects of our society and economy in the coming years.
# Original Text Length: 1521
#
# Original Text:
# The Internet of Things (IoT) is revolutionizing the way we interact with technology in our daily lives. IoT refers to the network of physical devices, vehicles, home appliances, and other items embedded with electronics, software, sensors, and network connectivity, which enables these objects to collect and exchange data. This interconnectedness allows for seamless communication between devices, leading to increased automation and efficiency in various sectors.  In smart homes, IoT devices like thermostats, lighting systems, and security cameras can be controlled remotely via smartphones, offering convenience and energy savings. In healthcare, wearable devices can monitor patients' vital signs and alert medical professionals in case of emergencies. The agricultural sector benefits from IoT through smart irrigation systems and crop monitoring sensors, optimizing resource use and increasing yields.  However, the rapid growth of IoT also raises concerns about data privacy and security. As more devices become connected, the potential for cyberattacks and data breaches increases. Additionally, the vast amount of data generated by IoT devices poses challenges in terms of storage, processing, and analysis.  Despite these challenges, the potential benefits of IoT are immense. From improving urban planning with smart city initiatives to enhancing manufacturing processes through industrial IoT applications, this technology is set to transform numerous aspects of our society and economy in the coming years.
#
# Summary Length: 226
#
# Summary:
# the internet of things (IoT) is revolutionizing the way we interact with technology in our daily lives. the technology is set to transform numerous aspects of our society and economy in the coming years, says dr. sanjay gupta.
